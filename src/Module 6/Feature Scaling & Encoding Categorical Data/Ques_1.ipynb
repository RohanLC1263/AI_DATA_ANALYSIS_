# %%
# Question 1: Feature Scaling
# Task: Explain why feature scaling is essential and demonstrate the impact of unscaled features on a machine learning model.




# Question 2: Min-Max Scaling
# Task: Implement Min-Max Scaling on the Iris dataset.



# Question 3: Standardization (Z-score Scaling)
# Task: Implement Standardization using Z-score scaling on the Iris dataset.




# Question 4: Robust Scaling
# Task: Implement Robust Scaling to handle outliers in the Iris dataset.

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.metrics import accuracy_score

# Load Iris dataset
iris = load_iris()
X = iris.data
y = iris.target
columns = iris.feature_names
iris_df = pd.DataFrame(X, columns=columns)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# -------------------------------
# 1. Accuracy without Scaling
# -------------------------------
knn_unscaled = KNeighborsClassifier()
knn_unscaled.fit(X_train, y_train)
y_pred_unscaled = knn_unscaled.predict(X_test)
acc_unscaled = accuracy_score(y_test, y_pred_unscaled)

# -------------------------------
# 2. Min-Max Scaling
# -------------------------------
minmax_scaler = MinMaxScaler()
X_train_minmax = minmax_scaler.fit_transform(X_train)
X_test_minmax = minmax_scaler.transform(X_test)

knn_minmax = KNeighborsClassifier()
knn_minmax.fit(X_train_minmax, y_train)
y_pred_minmax = knn_minmax.predict(X_test_minmax)
acc_minmax = accuracy_score(y_test, y_pred_minmax)

iris_minmax_df = pd.DataFrame(minmax_scaler.fit_transform(iris_df), columns=columns)

# -------------------------------
# 3. Standardization (Z-score)
# -------------------------------
zscore_scaler = StandardScaler()
iris_zscore_df = pd.DataFrame(zscore_scaler.fit_transform(iris_df), columns=columns)

# -------------------------------
# 4. Robust Scaling
# -------------------------------
robust_scaler = RobustScaler()
iris_robust_df = pd.DataFrame(robust_scaler.fit_transform(iris_df), columns=columns)

# -------------------------------
# Display Results
# -------------------------------
print("===== Model Accuracy Comparison =====")
print(f"Without Scaling Accuracy: {acc_unscaled:.2f}")
print(f"With Min-Max Scaling Accuracy: {acc_minmax:.2f}\n")

print("===== Min-Max Scaled Data (Head) =====")
print(iris_minmax_df.head(), "\n")

print("===== Z-Score Scaled Data (Head) =====")
print(iris_zscore_df.head(), "\n")

print("===== Robust Scaled Data (Head) =====")
print(iris_robust_df.head())
# Out:
# ===== Model Accuracy Comparison =====
# Without Scaling Accuracy: 1.00
# With Min-Max Scaling Accuracy: 1.00
#
# ===== Min-Max Scaled Data (Head) =====
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0           0.222222          0.625000           0.067797          0.041667
# 1           0.166667          0.416667           0.067797          0.041667
# 2           0.111111          0.500000           0.050847          0.041667
# 3           0.083333          0.458333           0.084746          0.041667
# 4           0.194444          0.666667           0.067797          0.041667
#
# ===== Z-Score Scaled Data (Head) =====
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0          -0.900681          1.019004          -1.340227         -1.315444
# 1          -1.143017         -0.131979          -1.340227         -1.315444
# 2          -1.385353          0.328414          -1.397064         -1.315444
# ...
